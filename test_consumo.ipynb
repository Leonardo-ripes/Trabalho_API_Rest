# %% [markdown]
# ### Consumindo API

# %%
import pandas as pd
## pandas readcsv
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Filter rows where 'Action' is in the 'listed_in' column
action_movies = df[df['listed_in'].str.contains('dsaddasdsadasd', case=False)]
if action_movies.empty:
    print("sem resultados")
else: 
    print('achou')
# Out:
# sem resultados

# %%
# Filter rows where 'Action' is in the 'listed_in' column
action_movies = df[df['title'].str.contains('Dick Johnson Is Dead', case=False)]
if action_movies.empty:
    print("sem resultados")
else: 
    print('achou title')
# Out:
# achou title

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
# search movies that release_year is between 2020 and 2022

json = {
    "start": "2020",
    "end": "2023",
    "method": "between",
    "date": "2021"
}


# between
# equalBigger
# equalLess
# equal
df[(df['release_year'] >= 2020) & (df['release_year'] <= 2021)]
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17       s18  TV Show                                    Falsa identidad
# 32       s33  TV Show                                      Sex Education
# 34       s35  TV Show                            Tayo and Little Wizards
# ...      ...      ...                                                ...
# 5972   s5973    Movie                                   #cats_the_mewvie
# 7594   s7595    Movie                 Norm of the North: Family Vacation
# 8099   s8100    Movie                                        Straight Up
# 8125   s8126  TV Show                                        Super Wings
# 8132   s8133  TV Show          Surviving R. Kelly Part II: The Reckoning
#
#                                            director  \
# ...

# %%
id = "s" + str(int(df['show_id'].max().split('s')[1]) + 1)
id
# Out:
# 's1000'

# %%
df['show_id'].tail(1).to_string().split('s')[1]
# Out:
# '8807'

# %%
id = 's' + str(int(df['show_id'].tail(1).to_string().split('s')[1]) + 1)
id
# Out:
# 's8808'

# %%
data = {
    "type" : "TV Show",
    "title" : "meu_filme",	
    "director" : "leo e vitor",
    "cast" : "leo e vitor",
    "country"	: "brazil",
    "date_added" : "2023",
    "release_year" : "2023",
    "rating" : "10",
    "duration" : "200",
    "listed_in" : "action, sci-fi",
    "description" : "movie about our college work"
}
id = 's' + str(int(df['show_id'].tail(1).to_string().split('s')[1]) + 1)

newMovie = {'show_id': id, 'type': data['type'], 'title': data['title'], 'director': data['director'], 'cast': data['cast'], 'country': data['country'], 'date_added': data['date_added'], 'release_year': data['release_year'], 'rating': data['rating'], 'duration': data['duration'], 'listed_in': data['listed_in'], 'description': data['description']}
df = df.append(newMovie, ignore_index=True)
df.tail(1)
# Out:
# C:\Users\garcez\AppData\Local\Temp\ipykernel_23404\2035201331.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newMovie, ignore_index=True)
#      show_id     type      title     director         cast country date_added  \
# 8807   s8808  TV Show  meu_filme  leo e vitor  leo e vitor  brazil       2023
#
#      release_year rating duration       listed_in  \
# 8807         2023     10      200  action, sci-fi
#
#                        description
# 8807  movie about our college work

# %%
id = "s8808"
updated_data = {
    "type" : "TV Show",
    "title" : "novo filme",	
    "director" : "leo e vitor",
    "cast" : "leo e vitor",
    "country"	: "brazil",
    "date_added" : "2023",
    "release_year" : "2023",
    "rating" : "10",
    "duration" : "200",
    "listed_in" : "action, sci-fi",
    "description" : "movie about our college work"
}

df.loc[df['show_id'] == id, updated_data.keys()] = updated_data.values()

df.tail(2)
# Out:
#      show_id     type       title     director         cast country  \
# 8807   s8808  TV Show  novo filme  leo e vitor  leo e vitor  brazil
# 8808   s8809  TV Show  novo filme  leo e vitor  leo e vitor  brazil
#
#      date_added release_year rating duration       listed_in  \
# 8807       2023         2023     10      200  action, sci-fi
# 8808       2023         2023     10      200  action, sci-fi
#
#                        description
# 8807  movie about our college work
# 8808  movie about our college work

# %%
from Movie import MovieSchema

movie_data = {
    "type" : "TV Show",
    "title" : "teeeeest",	
    "director" : "leo e vitor",
    "cast" : "leo e vitor",
    "country"	: "brazil",
    "date_added" : "2023",
    "release_year" : "2023",
    "rating" : "10",
    "duration" : "200",
    "listed_in" : "action, sci-fi",
    "description" : "movie about our college work"
}


movie_schema = MovieSchema()
validated_movie = movie_schema.load(movie_data)
id = 's' + str(int(df['show_id'].tail(1).to_string().split('s')[1]) + 1)
validated_movie['show_id'] = id

df.append(validated_movie, ignore_index=True).tail(2)

# %%
id = "s8808"
print(df.loc[df['show_id'] == id])
# Out:
#      show_id     type       title     director         cast country  \
# 8807   s8808  TV Show  novo filme  leo e vitor  leo e vitor  brazil
#
#      date_added release_year rating duration       listed_in  \
# 8807       2023         2023     10      200  action, sci-fi
#
#                        description
# 8807  movie about our college work

# %%
data = {
    "type" : "TV Show",
    "title" : "meu_filme",	
    "director" : "leo e vitor",
    "cast" : "leo e vitor",
    "country"	: "brazil",
    "date_added" : "2023",
    "release_year" : "2023",
    "rating" : "10",
    "duration" : "200",
    "listed_in" : "action, sci-fi",
    "description" : "movie about our college work"
}
id = 's' + str(int(df['show_id'].tail(1).to_string().split('s')[1]) + 1)

newMovie = {'show_id': id, 'type': data['type'], 'title': data['title'], 'director': data['director'], 'cast': data['cast'], 'country': data['country'], 'date_added': data['date_added'], 'release_year': data['release_year'], 'rating': data['rating'], 'duration': data['duration'], 'listed_in': data['listed_in'], 'description': data['description']}
df = df.append(newMovie, ignore_index=True)
df.tail(1)
# Out:
# C:\Users\garcez\AppData\Local\Temp\ipykernel_23404\2035201331.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newMovie, ignore_index=True)
#      show_id     type      title     director         cast country date_added  \
# 8808   s8809  TV Show  meu_filme  leo e vitor  leo e vitor  brazil       2023
#
#      release_year rating duration       listed_in  \
# 8808         2023     10      200  action, sci-fi
#
#                        description
# 8808  movie about our college work
